# %% [markdown]
# # Transfer Learning Arsitektur CONVNEXT type base

# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Non Augmentasi Data

# %% [markdown]
# ## Model epochs 50

# %%
# Library
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize
import numpy as np

#Data
train_dir = '/content/drive/MyDrive/Split Data Convnext/train'
val_dir = '/content/drive/MyDrive/Split Data Convnext/val'

#Parameter
batch_size = 32
lr=1e-4
epochs=50

#ImageDataGenerator & Augmentasi Data
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    directory=train_dir,target_size=(224, 224),batch_size=batch_size,color_mode='rgb')

val_data = valid_datagen.flow_from_directory(
    directory=val_dir,target_size=(224, 224),batch_size=batch_size,color_mode='rgb')

#base model
base_model = tf.keras.applications.convnext.ConvNeXtBase(
    weights='imagenet',   # Pre-trained weights ImageNet
    include_top=False,
    input_shape=(224, 224, 3)
)


#freeze layer terakhir dari base model untuk fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-5]:   #5 Lapisan terakhir di Freeze
    layer.trainable = False

model = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='sigmoid')
])

#Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='binary_crossentropy',metrics=['accuracy'])
model.summary()

#Callback EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

#Training model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs,
    callbacks=[early_stopping])
# Out:
# Found 1200 images belonging to 10 classes.
# Found 150 images belonging to 10 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 ━━━━━━━━━━━━━━━━━━━━ 16s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ convnext_base (Functional)           │ (None, 7, 7, 1024)          │      87,566,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       6,422,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 93,990,410 (358.54 MB)
#  Trainable params: 10,622,346 (40.52 MB)
#  Non-trainable params: 83,368,064 (318.02 MB)
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 862s 18s/step - accuracy: 0.1981 - loss: 0.5055 - val_accuracy: 0.5133 - val_loss: 0.2239
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 586ms/step - accuracy: 0.5124 - loss: 0.2419 - val_accuracy: 0.6067 - val_loss: 0.1901
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 591ms/step - accuracy: 0.6255 - loss: 0.1974 - val_accuracy: 0.6067 - val_loss: 0.1857
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 579ms/step - accuracy: 0.6586 - loss: 0.1772 - val_accuracy: 0.6933 - val_loss: 0.1669
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 508ms/step - accuracy: 0.7000 - loss: 0.1555 - val_accuracy: 0.6733 - val_loss: 0.1672
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 23s 513ms/step - accuracy: 0.7967 - loss: 0.1285 - val_accuracy: 0.6933 - val_loss: 0.1577
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 23s 530ms/step - accuracy: 0.8337 - loss: 0.1172 - val_accuracy: 0.6867 - val_loss: 0.1536
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 585ms/step - accuracy: 0.8341 - loss: 0.1101 - val_accuracy: 0.6800 - val_loss: 0.1547
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 515ms/step - accuracy: 0.8534 - loss: 0.1016 - val_accuracy: 0.7133 - val_loss: 0.1536
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 520ms/step - accuracy: 0.8517 - loss: 0.0927 - val_accuracy: 0.7067 - val_loss: 0.1527
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 540ms/step - accuracy: 0.8844 - loss: 0.0832 - val_accuracy: 0.7133 - val_loss: 0.1452
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 498ms/step - accuracy: 0.9036 - loss: 0.0737 - val_accuracy: 0.7133 - val_loss: 0.1454
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 498ms/step - accuracy: 0.9264 - loss: 0.0652 - val_accuracy: 0.6800 - val_loss: 0.1537
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 45s 616ms/step - accuracy: 0.9205 - loss: 0.0638 - val_accuracy: 0.7267 - val_loss: 0.1430
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 498ms/step - accuracy: 0.9328 - loss: 0.0583 - val_accuracy: 0.6800 - val_loss: 0.1576
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 480ms/step - accuracy: 0.9338 - loss: 0.0572 - val_accuracy: 0.7200 - val_loss: 0.1469
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 488ms/step - accuracy: 0.9373 - loss: 0.0541 - val_accuracy: 0.6933 - val_loss: 0.1619
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 509ms/step - accuracy: 0.9529 - loss: 0.0509 - val_accuracy: 0.7400 - val_loss: 0.1572
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 486ms/step - accuracy: 0.9495 - loss: 0.0451 - val_accuracy: 0.7267 - val_loss: 0.1549

# %% [markdown]
# ## Peforma Model & Evaluasi Metriks

# %%
#Plot Training

import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Akurasi Model Transfer Learning Convnext')
plt.xlabel('Epochs')
plt.ylabel('Akurasi')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Model Transfer Learning Convnext')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


test_dir= '/content/drive/MyDrive/Split Data Convnext/test'
test_datagen = ImageDataGenerator(rescale=1./255)

#Load data test
test_data = test_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(224,224),
    batch_size=batch_size,
    color_mode='rgb',
    class_mode='binary',
    shuffle=False
)

#Prediksi model pada data test
predictions = model.predict(test_data, verbose=1)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = test_data.classes


#Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)

#Visualisasi Confusion Matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=test_data.class_indices.keys(),
            yticklabels=test_data.class_indices.keys())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Menampilkan laporan klasifikasi
print("Classification Report:\n", classification_report(true_labels, predicted_labels))

# Menghitung akurasi per kelas
accuracyclass = cm.diagonal() / cm.sum(axis=1)

# Menampilkan akurasi per kelas
print("Accuracy per Class:")
for class_name, accuracy in zip(test_data.class_indices.keys(), accuracyclass):
    print(f"{class_name}: {accuracy * 100:.2f}%")
# Out:
# Found 150 images belonging to 10 classes.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 68s 16s/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.53      0.62        15
#            1       0.65      0.73      0.69        15
#            2       0.59      0.67      0.62        15
#            3       0.53      0.53      0.53        15
#            4       0.63      0.80      0.71        15
#            5       0.67      0.67      0.67        15
#            6       0.76      0.87      0.81        15
#            7       0.71      0.80      0.75        15
#            8       0.89      0.53      0.67        15
#            9       0.92      0.80      0.86        15
#
#     accuracy                           0.69       150
#    macro avg       0.71      0.69      0.69       150
# weighted avg       0.71      0.69      0.69       150
#
# Accuracy per Class:
# Cacomantis Merulinus: 53.33%
# Culicicapa Ceylonensis: 73.33%
# Geopelia Striata: 66.67%
# Halcyon Smyrnensis: 53.33%
# Ninox Scutulata: 80.00%
# Orthotomus Ruficeps: 66.67%
# Pitta Sordida: 86.67%
# Prinia Flaviventris: 80.00%
# Spilopelia Chinensis: 53.33%
# Surniculus Lugubris: 80.00%

# %% [markdown]
# ## Prediksi

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Cacomantis Merulinus/241965_chunk_35.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# kelas prediksi: 0
# label prediksi: Cacomantis Merulinus

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Culicicapa Ceylonensis/19711_chunk_2.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kelas prediksi: 1
# label prediksi: Culicicapa Ceylonensis

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Halcyon Smyrnensis/477294_chunk_0.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kelas prediksi: 3
# label prediksi: Halcyon Smyrnensis

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Geopelia Striata/40043_chunk_0.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kelas prediksi: 2
# label prediksi: Geopelia Striata

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Ninox Scutulata/608654_chunk_8.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kelas prediksi: 4
# label prediksi: Ninox Scutulata

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Ninox Scutulata/608654_chunk_8.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kelas prediksi: 4
# label prediksi: Ninox Scutulata

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Orthotomus Ruficeps/498827_chunk_6.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kelas prediksi: 5
# label prediksi: Orthotomus Ruficeps

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Pitta Sordida/202674_chunk_6.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# kelas prediksi: 6
# label prediksi: Pitta Sordida

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Prinia Flaviventris/519926_chunk_5.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# kelas prediksi: 7
# label prediksi: Prinia Flaviventris

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Spilopelia Chinensis/311498_chunk_2.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kelas prediksi: 8
# label prediksi: Spilopelia Chinensis

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Surniculus Lugubris/158707_chunk_21.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# kelas prediksi: 9
# label prediksi: Surniculus Lugubris

# %% [markdown]
# ## Save Model

# %%
model_save_path = '/content/drive/MyDrive/convnextnonaugmentasiepochs50.keras'  # Path untuk menyimpan model
model.save(model_save_path)

# %% [markdown]
# # Augmentasi Data

# %% [markdown]
# ## Model epochs 50

# %%
# Library
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize
import numpy as np

#Data
train_dir = '/content/drive/MyDrive/Split Data Convnext/train'
val_dir = '/content/drive/MyDrive/Split Data Convnext/val'

#Parameter
batch_size = 32
lr=1e-4
epochs=50

#ImageDataGenerator & Augmentasi Data
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)
valid_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    directory=train_dir,target_size=(224, 224),batch_size=batch_size,color_mode='rgb')

val_data = valid_datagen.flow_from_directory(
    directory=val_dir,target_size=(224, 224),batch_size=batch_size,color_mode='rgb')

#base model
base_model = tf.keras.applications.convnext.ConvNeXtBase(
    weights='imagenet',   # Pre-trained weights ImageNet
    include_top=False,
    input_shape=(224, 224, 3)
)


#freeze layer terakhir dari base model untuk fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-5]:   #5 Lapisan terakhir di Freeze
    layer.trainable = False

model = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='sigmoid')
])

#Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='binary_crossentropy',metrics=['accuracy'])
model.summary()

#Callback EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

#Training model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs,
    callbacks=[early_stopping])
# Out:
# Found 1200 images belonging to 10 classes.
# Found 150 images belonging to 10 classes.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ convnext_base (Functional)           │ (None, 7, 7, 1024)          │      87,566,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       6,422,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 93,990,410 (358.54 MB)
#  Trainable params: 10,622,346 (40.52 MB)
#  Non-trainable params: 83,368,064 (318.02 MB)
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.1421 - loss: 0.5259 - val_accuracy: 0.3667 - val_loss: 0.2723
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 63s 795ms/step - accuracy: 0.2773 - loss: 0.3211 - val_accuracy: 0.4400 - val_loss: 0.2509
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 763ms/step - accuracy: 0.3159 - loss: 0.3061 - val_accuracy: 0.5400 - val_loss: 0.2346
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 766ms/step - accuracy: 0.3356 - loss: 0.2926 - val_accuracy: 0.5867 - val_loss: 0.2181
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 787ms/step - accuracy: 0.3871 - loss: 0.2814 - val_accuracy: 0.5467 - val_loss: 0.2204
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 858ms/step - accuracy: 0.4319 - loss: 0.2682 - val_accuracy: 0.5400 - val_loss: 0.2155
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 852ms/step - accuracy: 0.4460 - loss: 0.2614 - val_accuracy: 0.6000 - val_loss: 0.2027
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 797ms/step - accuracy: 0.4408 - loss: 0.2565 - val_accuracy: 0.6200 - val_loss: 0.1975
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 813ms/step - accuracy: 0.4730 - loss: 0.2440 - val_accuracy: 0.6400 - val_loss: 0.1953
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 789ms/step - accuracy: 0.4701 - loss: 0.2485 - val_accuracy: 0.6533 - val_loss: 0.1919
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 813ms/step - accuracy: 0.5278 - loss: 0.2387 - val_accuracy: 0.6267 - val_loss: 0.1932
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 773ms/step - accuracy: 0.4995 - loss: 0.2393 - val_accuracy: 0.5933 - val_loss: 0.1901
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 795ms/step - accuracy: 0.4996 - loss: 0.2328 - val_accuracy: 0.6533 - val_loss: 0.1815
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 792ms/step - accuracy: 0.5318 - loss: 0.2272 - val_accuracy: 0.6733 - val_loss: 0.1762
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 37s 818ms/step - accuracy: 0.5394 - loss: 0.2216 - val_accuracy: 0.6667 - val_loss: 0.1767
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 796ms/step - accuracy: 0.5391 - loss: 0.2245 - val_accuracy: 0.6667 - val_loss: 0.1783
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 36s 778ms/step - accuracy: 0.5361 - loss: 0.2209 - val_accuracy: 0.6867 - val_loss: 0.1717
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 774ms/step - accuracy: 0.5462 - loss: 0.2129 - val_accuracy: 0.6333 - val_loss: 0.1680
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 798ms/step - accuracy: 0.5953 - loss: 0.2056 - val_accuracy: 0.6933 - val_loss: 0.1651
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 793ms/step - accuracy: 0.5742 - loss: 0.2081 - val_accuracy: 0.6933 - val_loss: 0.1616
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 776ms/step - accuracy: 0.5836 - loss: 0.2012 - val_accuracy: 0.7133 - val_loss: 0.1575
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 788ms/step - accuracy: 0.5768 - loss: 0.2040 - val_accuracy: 0.6733 - val_loss: 0.1579
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 792ms/step - accuracy: 0.5890 - loss: 0.2100 - val_accuracy: 0.6600 - val_loss: 0.1664
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 36s 780ms/step - accuracy: 0.6120 - loss: 0.1984 - val_accuracy: 0.7067 - val_loss: 0.1574
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 768ms/step - accuracy: 0.5993 - loss: 0.1967 - val_accuracy: 0.7000 - val_loss: 0.1550
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 854ms/step - accuracy: 0.6215 - loss: 0.1924 - val_accuracy: 0.6733 - val_loss: 0.1561
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 796ms/step - accuracy: 0.6153 - loss: 0.1852 - val_accuracy: 0.6867 - val_loss: 0.1580
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 786ms/step - accuracy: 0.6396 - loss: 0.1788 - val_accuracy: 0.7000 - val_loss: 0.1583
# Epoch 29/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 777ms/step - accuracy: 0.6134 - loss: 0.1828 - val_accuracy: 0.6933 - val_loss: 0.1564
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 828ms/step - accuracy: 0.6529 - loss: 0.1804 - val_accuracy: 0.7067 - val_loss: 0.1500
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 801ms/step - accuracy: 0.6264 - loss: 0.1851 - val_accuracy: 0.7267 - val_loss: 0.1468
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 747ms/step - accuracy: 0.6502 - loss: 0.1800 - val_accuracy: 0.7333 - val_loss: 0.1518
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 776ms/step - accuracy: 0.6083 - loss: 0.1849 - val_accuracy: 0.7400 - val_loss: 0.1396
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 837ms/step - accuracy: 0.6432 - loss: 0.1744 - val_accuracy: 0.7400 - val_loss: 0.1439
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 788ms/step - accuracy: 0.6445 - loss: 0.1779 - val_accuracy: 0.7067 - val_loss: 0.1453
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 37s 829ms/step - accuracy: 0.6569 - loss: 0.1681 - val_accuracy: 0.7467 - val_loss: 0.1416
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 44s 909ms/step - accuracy: 0.6434 - loss: 0.1802 - val_accuracy: 0.7133 - val_loss: 0.1464
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 924ms/step - accuracy: 0.6918 - loss: 0.1582 - val_accuracy: 0.7267 - val_loss: 0.1415

# %% [markdown]
# ## Peforma Model & Evaluasi Metriks

# %%
#Plot Training

import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Akurasi Model Transfer Learning Convnext')
plt.xlabel('Epochs')
plt.ylabel('Akurasi')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Model Transfer Learning Convnext')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


test_dir= '/content/drive/MyDrive/Split Data Convnext/test'
test_datagen = ImageDataGenerator(rescale=1./255)

#Load data test
test_data = test_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(224,224),
    batch_size=batch_size,
    color_mode='rgb',
    class_mode='binary',
    shuffle=False
)

#Prediksi model pada data test
predictions = model.predict(test_data, verbose=1)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = test_data.classes


#Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)

#Visualisasi Confusion Matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=test_data.class_indices.keys(),
            yticklabels=test_data.class_indices.keys())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Menampilkan laporan klasifikasi
print("Classification Report:\n", classification_report(true_labels, predicted_labels))

# Menghitung akurasi per kelas
accuracyclass = cm.diagonal() / cm.sum(axis=1)

# Menampilkan akurasi per kelas
print("Accuracy per Class:")
for class_name, accuracy in zip(test_data.class_indices.keys(), accuracyclass):
    print(f"{class_name}: {accuracy * 100:.2f}%")
# Out:
# Found 150 images belonging to 10 classes.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.47      0.56        15
#            1       0.85      0.73      0.79        15
#            2       0.65      0.73      0.69        15
#            3       0.56      0.60      0.58        15
#            4       0.57      0.80      0.67        15
#            5       0.58      0.73      0.65        15
#            6       0.86      0.80      0.83        15
#            7       0.80      0.80      0.80        15
#            8       0.75      0.60      0.67        15
#            9       0.92      0.80      0.86        15
#
#     accuracy                           0.71       150
#    macro avg       0.72      0.71      0.71       150
# weighted avg       0.72      0.71      0.71       150
#
# Accuracy per Class:
# Cacomantis Merulinus: 46.67%
# Culicicapa Ceylonensis: 73.33%
# Geopelia Striata: 73.33%
# Halcyon Smyrnensis: 60.00%
# Ninox Scutulata: 80.00%
# Orthotomus Ruficeps: 73.33%
# Pitta Sordida: 80.00%
# Prinia Flaviventris: 80.00%
# Spilopelia Chinensis: 60.00%
# Surniculus Lugubris: 80.00%

# %% [markdown]
# ## Prediksi

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Cacomantis Merulinus/241965_chunk_35.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# kelas prediksi: 0
# label prediksi: Cacomantis Merulinus

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Culicicapa Ceylonensis/19711_chunk_2.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kelas prediksi: 1
# label prediksi: Culicicapa Ceylonensis

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Halcyon Smyrnensis/477294_chunk_0.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kelas prediksi: 3
# label prediksi: Halcyon Smyrnensis

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Geopelia Striata/40043_chunk_0.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kelas prediksi: 2
# label prediksi: Geopelia Striata

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Ninox Scutulata/608654_chunk_8.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kelas prediksi: 4
# label prediksi: Ninox Scutulata

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Ninox Scutulata/608654_chunk_8.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kelas prediksi: 4
# label prediksi: Ninox Scutulata

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Orthotomus Ruficeps/498827_chunk_6.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kelas prediksi: 5
# label prediksi: Orthotomus Ruficeps

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Pitta Sordida/202674_chunk_6.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kelas prediksi: 6
# label prediksi: Pitta Sordida

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Prinia Flaviventris/519926_chunk_5.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kelas prediksi: 7
# label prediksi: Prinia Flaviventris

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Spilopelia Chinensis/311498_chunk_2.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kelas prediksi: 8
# label prediksi: Spilopelia Chinensis

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

#Path ke gambar input
image_path = '/content/drive/MyDrive/Split Data Convnext/test/Surniculus Lugubris/158707_chunk_21.png'

#Pre-processing gambar
img = image.load_img(image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

#Prediksi  model
predicted_probabilities = model.predict(img_array, verbose=1)
predicted_class = np.argmax(predicted_probabilities, axis=1)[0]

#Mapping indeks ke kelas
class_indices = test_data.class_indices
class_labels = {v: k for k, v in class_indices.items()}
predicted_label = class_labels[predicted_class]

#Menampilkan hasil prediksi
print(f"kelas prediksi: {predicted_class}")
print(f"label prediksi: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kelas prediksi: 9
# label prediksi: Surniculus Lugubris

# %% [markdown]
# ## Save Model

# %%
model_save_path = '/content/drive/MyDrive/convnextaugmentasiepochs50.keras'  # Path untuk menyimpan model
model.save(model_save_path)
